# %%
# To predict whether a person is a high-risk or low-risk borrower based on their financial profile using a decision tree.

# %%
# import necessary libraries
import pandas as pd 
import numpy as np
import seaborn as sns 
import mtplotlib.pyplot as plt
